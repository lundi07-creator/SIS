# %% [markdown]
# # 03 – Bakåtriktade metoder
#
# ## Innehål
# - Singh-metoden
# - Spänningsfallsbaserad impedansmetod (SI)
# - Effektmetoden
# - Jämförelser

# %% [markdown]
# ## Import och setup

# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from src.backward_methods import singh_method, si_method, effect_method, estimate_temperature
from src.utils import to_phasor, from_phasor

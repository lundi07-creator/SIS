# %% [markdown]
# # 02 – Databehandling
#
# ## Innehål
# - Läs in rådata
# - Mappa mät-ID till elektriska storheter
# - Synka tidsstämplar
# - Kontrollera strömriktning
# - Spara processed data

# %% [markdown]
# ## Import och setup

# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
from src.data_loader import load_raw, sync_timestamps, save_processed

# %% [markdown]
# ## Läsa rådata

# %%
# Läs data från sändar- och mottagarstation
# df_sending = load_raw('../data/raw/sending_end.csv')
# df_receiving = load_raw('../data/raw/receiving_end.csv')

# print(df_sending.head())
# print(df_receiving.head())

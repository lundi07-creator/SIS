# %% [markdown]
# # 02 – Forward model
#
# ## Innehål
# - Theoretical forward model for cable resistance and temperature
# - Fixed-load model implementation
# - Prediction of voltage and power changes with temperature

# %% [markdown]
# ## Import och setup

# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from src.forward_model import forward_model_fixed_load, estimate_voltage_change
from src.utils import to_phasor, from_phasor

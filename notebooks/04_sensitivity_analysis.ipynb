# %% [markdown]
# # 04 – Känslighetsanalys
#
# ## Innehål
# - Vinkeloffset
# - Magnitudfel
# - Lutningsberäkning nära nollfel

# %% [markdown]
# ## Import och setup

# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from src.sensitivity import apply_angle_offset, apply_magnitude_error, sensitivity_slope

# %% [markdown]
# # 05 – Figurgenerering
#
# Genererar alla figurer som används i kapitel 4 av thesis.

# %% [markdown]
# ## Import och setup

# %%
import sys
sys.path.append('../')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Konfigurera matplotlib för thesis-stil
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['font.size'] = 11
